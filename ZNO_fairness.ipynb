# %%
import numpy as np 
import pandas as pd
from FairnessEvaluator import FairnessEvaluator

# %% [markdown]
# # Spanish

# %%
data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Spa.csv', sep=',')
y = data_raw['SpaTestStatus'].to_numpy()
data_raw['label_value'] = y

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTypeName',
                      metrics=['fpr','fnr', 'tpr'], #with tp in bound but recall 0
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      metric_fairness_bounds={'tpr': [0.99,1.01]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 127 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-150) columns and 0 (-173) elements
# Clp0000I Optimal - objective value 4.9
# Coin0511I After Postsolve, objective 4.9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 4.9 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 681 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-147) columns and 16 (-503) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'TerTypeName',
                      metrics=['fpr','fnr', 'tpr'], #with tp in bound but recall 0
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      metric_fairness_bounds={'tpr': [0.99,1.01]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 127 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-150) columns and 0 (-173) elements
# Clp0000I Optimal - objective value 4.9
# Coin0511I After Postsolve, objective 4.9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 4.9 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 681 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-147) columns and 16 (-503) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTer',
                      metrics=['fpr','fnr', 'tp'], #with tp in bound but recall 0
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 127 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-150) columns and 0 (-173) elements
# Clp0000I Optimal - objective value 4.9
# Coin0511I After Postsolve, objective 4.9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 4.9 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 2389 small elements
# Coin0506I Presolve 20 (0) rows, 8 (-142) columns and 48 (-563) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %% [markdown]
# # Franch language

# %%
data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Fra.csv', sep=',')
y = data_raw['FraTestStatus'].to_numpy()
data_raw['label_value'] = y

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.99,1.01]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 377 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-414) columns and 0 (-451) elements
# Clp0000I Optimal - objective value 14
# Coin0511I After Postsolve, objective 14, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 14 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 1959 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-411) columns and 16 (-1337) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'TerTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      metric_fairness_bounds={'tpr': [0.99,1.01]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 377 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-414) columns and 0 (-451) elements
# Clp0000I Optimal - objective value 14
# Coin0511I After Postsolve, objective 14, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 14 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 1959 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-411) columns and 16 (-1337) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTer',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      metric_fairness_bounds={'tpr': [0.9,1.1]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 377 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-414) columns and 0 (-451) elements
# Clp0000I Optimal - objective value 14
# Coin0511I After Postsolve, objective 14, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 14 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 6683 small elements
# Coin0506I Presolve 19 (-1) rows, 7 (-407) columns and 50 (-1547) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %% [markdown]
# # Deu language

# %%
data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Deu.csv', sep=',')
y = data_raw['DeuTestStatus'].to_numpy()
data_raw['label_value'] = y

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.99,1.01]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 1617 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-1825) columns and 0 (-2033) elements
# Clp0000I Optimal - objective value 63.7
# Coin0511I After Postsolve, objective 63.7, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 63.7 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 8501 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-1822) columns and 18 (-6081) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'TerTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      metric_fairness_bounds={'tpr': [0.9,1.1]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 1617 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-1825) columns and 0 (-2033) elements
# Clp0000I Optimal - objective value 63.7
# Coin0511I After Postsolve, objective 63.7, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 63.7 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.03
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 8501 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-1822) columns and 16 (-6083) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTer',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      metric_fairness_bounds={'tpr': [0.99,1.01]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 1617 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-1825) columns and 0 (-2033) elements
# Clp0000I Optimal - objective value 63.7
# Coin0511I After Postsolve, objective 63.7, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 63.7 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 29305 small elements
# Coin0506I Presolve 19 (-1) rows, 7 (-1818) columns and 50 (-7145) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %% [markdown]
# # Chemistry

# %%
data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Chem.csv', sep=',')
y = data_raw['ChemTestStatus'].to_numpy()
data_raw['label_value'] = y
# Out:
# /var/folders/mr/rk8jvb8d45z63grsh03yvfw40000gn/T/ipykernel_27727/3393921368.py:1: DtypeWarning: Columns (138,139,140,144,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Chem.csv', sep=',')

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.99,1.01]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 8760 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-9809) columns and 0 (-10858) elements
# Clp0000I Optimal - objective value 343
# Coin0511I After Postsolve, objective 343, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 343 - 0 iterations time 0.012, Presolve 0.01, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.08
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 45898 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-9806) columns and 16 (-32558) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'TerTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.9,1.1]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 8760 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-9809) columns and 0 (-10858) elements
# Clp0000I Optimal - objective value 343
# Coin0511I After Postsolve, objective 343, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 343 - 0 iterations time 0.012, Presolve 0.01, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.12
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 45898 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-9806) columns and 16 (-32558) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTer',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 8760 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-9809) columns and 0 (-10858) elements
# Clp0000I Optimal - objective value 343
# Coin0511I After Postsolve, objective 343, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 343 - 0 iterations time 0.012, Presolve 0.01, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.09
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 156530 small elements
# Coin0506I Presolve 20 (0) rows, 8 (-9801) columns and 48 (-39602) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %% [markdown]
# # Physics

# %%
data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Phys.csv', sep=',')
y = data_raw['PhysTestStatus'].to_numpy()
data_raw['label_value'] = y
# Out:
# /var/folders/mr/rk8jvb8d45z63grsh03yvfw40000gn/T/ipykernel_27727/2642252579.py:1: DtypeWarning: Columns (118,119,120,122,124,125,126,127,138,139,140,144,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Phys.csv', sep=',')

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 21275 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-23202) columns and 0 (-25129) elements
# Clp0000I Optimal - objective value 812
# Coin0511I After Postsolve, objective 812, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 812 - 0 iterations time 0.062, Presolve 0.06, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.19   (Wallclock seconds):       0.40
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 110229 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-23199) columns and 16 (-75371) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'TerTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 21275 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-23202) columns and 0 (-25129) elements
# Clp0000I Optimal - objective value 812
# Coin0511I After Postsolve, objective 812, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 812 - 0 iterations time 0.062, Presolve 0.06, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.23   (Wallclock seconds):       0.66
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 110229 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-23199) columns and 16 (-75371) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTer',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      metric_fairness_bounds={'tpr': [0.95,1.05]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 21275 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-23202) columns and 0 (-25129) elements
# Clp0000I Optimal - objective value 812
# Coin0511I After Postsolve, objective 812, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 812 - 0 iterations time 0.062, Presolve 0.06, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.20   (Wallclock seconds):       0.60
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 385205 small elements
# Coin0506I Presolve 19 (-1) rows, 7 (-23195) columns and 50 (-78785) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %% [markdown]
# # English

# %%
data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Eng.csv', sep=',')
y = data_raw['EngTestStatus'].to_numpy()
data_raw['label_value'] = y
# Out:
# /var/folders/mr/rk8jvb8d45z63grsh03yvfw40000gn/T/ipykernel_72157/1220258523.py:1: DtypeWarning: Columns (122,138,139,140,142,144,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Eng.csv', sep=',')

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 114139 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-127714) columns and 0 (-141289) elements
# Clp0000I Optimal - objective value 4469.5
# Coin0511I After Postsolve, objective 4469.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 4469.5 - 0 iterations time 1.392, Presolve 1.39, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       3.08   (Wallclock seconds):       3.78
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 597845 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-127711) columns and 16 (-423851) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'TerTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 114139 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-127714) columns and 0 (-141289) elements
# Clp0000I Optimal - objective value 4469.5
# Coin0511I After Postsolve, objective 4469.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 4469.5 - 0 iterations time 1.742, Presolve 1.74, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       2.92   (Wallclock seconds):       3.22
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 597845 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-127711) columns and 16 (-423851) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTer',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 28 2021
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 114139 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-127714) columns and 0 (-141289) elements
# Clp0000I Optimal - objective value 4469.5
# Coin0511I After Postsolve, objective 4469.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 4469.5 - 0 iterations time 1.822, Presolve 1.82, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       2.73   (Wallclock seconds):       3.19
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 2079349 small elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %% [markdown]
# # History

# %%
data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Hist.csv', sep=',')
y = data_raw['HistTestStatus'].to_numpy()
data_raw['label_value'] = y
# Out:
# /var/folders/mr/rk8jvb8d45z63grsh03yvfw40000gn/T/ipykernel_89760/2968454108.py:1: DtypeWarning: Columns (122,138,139,140,142,144,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_raw = pd.read_csv('/Users/Air/iCloud Drive (Archive)/Documents/УКУ/NY/Datasets_ZNO/ZNO_Hist.csv', sep=',')

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 163532 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-199373) columns and 0 (-235214) elements
# Clp0000I Optimal - objective value 6977.6
# Coin0511I After Postsolve, objective 6977.6, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 6977.6 - 0 iterations time 3.072, Presolve 3.07, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       6.50   (Wallclock seconds):       7.44
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 889342 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-199370) columns and 16 (-705626) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'TerTypeName',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 163532 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-199373) columns and 0 (-235214) elements
# Clp0000I Optimal - objective value 6977.6
# Coin0511I After Postsolve, objective 6977.6, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 6977.6 - 0 iterations time 3.412, Presolve 3.41, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       6.98   (Wallclock seconds):       9.08
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 889342 small elements
# Coin0506I Presolve 7 (-1) rows, 3 (-199370) columns and 16 (-705626) elements
# ...

# %%
fo.plot(x_scale_perc=True)

# %%
fo = FairnessEvaluator(data_raw,
                      'label_value',
                      'SexTer',
                      metrics=['fpr','fnr', 'tpr'], 
                      metrics_to_plot=['fnr','fpr', 'prec'],
                      fully_constrained=False,
                      precision_ub = 0.7,
                      #metric_fairness_bounds={'tpr': [0.995,1.005]}
                      )       
df = fo.evaluate()
print(df)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 163532 small elements
# Coin0506I Presolve 0 (-2) rows, 0 (-199373) columns and 0 (-235214) elements
# Clp0000I Optimal - objective value 6977.6
# Coin0511I After Postsolve, objective 6977.6, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 6977.6 - 0 iterations time 2.952, Presolve 2.95, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       6.93   (Wallclock seconds):       10.67
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 3127278 small elements
# Coin0506I Presolve 20 (0) rows, 8 (-199365) columns and 48 (-860134) elements
# ...

# %%
fo.plot(x_scale_perc=True)
